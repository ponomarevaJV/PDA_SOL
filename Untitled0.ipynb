# %% [markdown]
# <a href="https://colab.research.google.com/github/ponomarevaJV/PDA_SOL/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Импорт модулей, не связанныех с PySpark.
import os
import sys
import pandas as pd
from pandas import DataFrame
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
import matplotlib
from mpl_toolkits.mplot3d import Axes3D
import math
from IPython.core.interactiveshell import InteractiveShell
from datetime import *
import statistics as stats
# Это помогает автоматически распечатывать элементы без явного использования «печати».
InteractiveShell.ast_node_interactivity = "all"
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
! pip install pyspark
# Out:
# Requirement already satisfied: pyspark in /usr/local/lib/python3.10/dist-packages (3.5.1)
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.10/dist-packages (from pyspark) (0.10.9.7)

# %%
# Импорт модулей, связанных с PySpark.
import pyspark
from pyspark.rdd import RDD
from pyspark.sql import Row
from pyspark.sql import DataFrame
from pyspark.sql import SparkSession
from pyspark.sql import SQLContext
from pyspark.sql import functions
from pyspark.sql.functions import lit, desc, col, size, array_contains\
, isnan, udf, hour, array_min, array_max, countDistinct, count, sum, min, max
from pyspark.sql.types import *

MAX_MEMORY = '15G'
# Инициализировать сеанс Spark.
conf = pyspark.SparkConf().setMaster("local[*]") \
        .set('spark.executor.heartbeatInterval', 10000) \
        .set('spark.network.timeout', 10000) \
        .set("spark.core.connection.ack.wait.timeout", "3600") \
        .set("spark.executor.memory", MAX_MEMORY) \
        .set("spark.driver.memory", MAX_MEMORY)
def init_spark():
    spark = SparkSession \
        .builder \
        .appName("Pyspark guide") \
        .config(conf=conf) \
        .getOrCreate()
    return spark

spark = init_spark()
filename_data = '/content/drive/MyDrive/2 семестр /Корпоративные платформы для хранения и анализа больших данных /5лб/Walmart_sales.csv' # Загрузите данные в текущий каталог Colab.

df = spark.read.option("header", True).csv(filename_data)
print('Data frame type: ' + str(type(df)))
# Out:
# Data frame type: <class 'pyspark.sql.dataframe.DataFrame'>

# %%
print('Обзор данных')
df.printSchema()
print('Обзор столбцов')
pd.DataFrame(df.dtypes, columns = ['Column Name','Data type'])
# Out:
# Обзор данных
# root
#  |-- Store: string (nullable = true)
#  |-- Date: string (nullable = true)
#  |-- Weekly_Sales: string (nullable = true)
#  |-- Holiday_Flag: string (nullable = true)
#  |-- Temperature: string (nullable = true)
#  |-- Fuel_Price: string (nullable = true)
#  |-- CPI: string (nullable = true)
#  |-- Unemployment: string (nullable = true)
#
# Обзор столбцов
#     Column Name Data type
# 0         Store    string
# 1          Date    string
# 2  Weekly_Sales    string
# 3  Holiday_Flag    string
# 4   Temperature    string
# 5    Fuel_Price    string
# 6           CPI    string
# 7  Unemployment    string

# %%
print(f'Общее количество {df.count()} строк, печатаем несколько первых строк:')
df.limit(4).toPandas()
# Out:
# Общее количество 6435 строк, печатаем несколько первых строк:
#   Store        Date Weekly_Sales Holiday_Flag Temperature Fuel_Price  \
# 0     1  05-02-2010    1643690.9            0       42.31      2.572
# 1     1  12-02-2010   1641957.44            1       38.51      2.548
# 2     1  19-02-2010   1611968.17            0       39.93      2.514
# 3     1  26-02-2010   1409727.59            0       46.63      2.561
#
#            CPI Unemployment
# 0  211.0963582        8.106
# 1  211.2421698        8.106
# 2  211.2891429        8.106
# 3  211.3196429        8.106

# %%
print('Обзор столбцов')
pd.DataFrame(df.dtypes, columns = ['Column Name','Data type'])
# Out:
# Обзор столбцов
#     Column Name Data type
# 0         Store    string
# 1          Date    string
# 2  Weekly_Sales    string
# 3  Holiday_Flag    string
# 4   Temperature    string
# 5    Fuel_Price    string
# 6           CPI    string
# 7  Unemployment    string

# %%
string_columns = ['	Store','Date','Temperature','Unemployment','Holiday_Flag']
numeric_columns = ['Weekly_Sales','Fuel_Price','CPI']
array_columns = []
missing_values = {}
for index, column in enumerate(df.columns):
    if column in string_columns:
        missing_count = df.filter(col(column).eqNullSafe(None) | col(column).isNull()).count()
        missing_values.update({column: missing_count})
    if column in numeric_columns:
        missing_count = df.where(col(column).isin([None, np.nan])).count()
        missing_values.update({column: missing_count})
    if column in array_columns:
        missing_count = df.filter(array_contains(df[column], 0) | array_contains(df[column], np.nan)).count()
        missing_values.update({column: missing_count})
missing_df = pd.DataFrame.from_dict([missing_values])
missing_df
# Out:
#    Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  CPI  \
# 0     0             0             0            0           0    0
#
#    Unemployment
# 0             0

# %%
# Преобразование столбца метки времени в Datetime.Datetime, чтобы позже использовать его для функции .withColumn.
def to_day(t):
    return datetime.strptime(t, "%Y-%m-%d %H:%M").day

# Регистрация вспомогательной функции to_time в структуре UDF pyspark
udf_to_day = udf(to_day, IntegerType())

# %%
df = df.withColumn('Datetime',
    udf_to_day(df.Date))
df = df.withColumn('Date',
    udf_to_day(df.Date))
print('Обзор столбцов')
pd.DataFrame(df.dtypes, columns = ['Column Name','Date type'])
# Out:
# Обзор столбцов
#     Column Name Date type
# 0         Store    string
# 1          Date       int
# 2  Weekly_Sales    string
# 3  Holiday_Flag    string
# 4   Temperature    string
# 5    Fuel_Price    string
# 6           CPI    string
# 7  Unemployment    string
# 8      Datetime       int

# %%
from pyspark.sql import functions as F

df = df.withColumn("Datetime", F.to_date(df['Date'], "dd-MM-yy"))

# %%
pandas_df = df.limit(10).toPandas()
# Out:
# ---------------------------------------------------------------------------
# PythonException                           Traceback (most recent call last)
# <ipython-input-95-01689698a977> in <cell line: 1>()
# ----> 1 pandas_df = df.limit(10).toPandas()
#
# /usr/local/lib/python3.10/dist-packages/pyspark/sql/pandas/conversion.py in toPandas(self)
#     200
#     201         # Below is toPandas without Arrow optimization.
# --> 202         rows = self.collect()
#     203         if len(rows) > 0:
#     204             pdf = pd.DataFrame.from_records(
#
# /usr/local/lib/python3.10/dist-packages/pyspark/sql/dataframe.py in collect(self)
#    1259         """
#    1260         with SCCallSiteSync(self._sc):
# -> 1261             sock_info = self._jdf.collectToPython()
#    1262         return list(_load_from_socket(sock_info, BatchedSerializer(CPickleSerializer())))
#    1263
#
# /usr/local/lib/python3.10/dist-packages/py4j/java_gateway.py in __call__(self, *args)
#    1320
#    1321         answer = self.gateway_client.send_command(command)
# -> 1322         return_value = get_return_value(
#    1323             answer, self.gateway_client, self.target_id, self.name)
#    1324
#
# /usr/local/lib/python3.10/dist-packages/pyspark/errors/exceptions/captured.py in deco(*a, **kw)
#     183                 # Hide where the exception came from that shows a non-Pythonic
#     184                 # JVM exception message.
# --> 185                 raise converted from None
#     186             else:
#     187                 raise
#
# PythonException:
#   An exception was thrown from the Python worker. Please see the stack trace below.
# Traceback (most recent call last):
#   File "<ipython-input-56-aed71e51edc2>", line 3, in to_day
#   File "/usr/lib/python3.10/_strptime.py", line 568, in _strptime_datetime
#     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#   File "/usr/lib/python3.10/_strptime.py", line 349, in _strptime
#     raise ValueError("time data %r does not match format %r" %
# ValueError: time data '05-02-2010' does not match format '%Y/%m/%d %H:%M'
