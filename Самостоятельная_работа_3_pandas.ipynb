# %% [markdown]
# <a href="https://colab.research.google.com/github/ponomarevaJV/PDA_SOL/blob/main/%D0%A1%D0%B0%D0%BC%D0%BE%D1%81%D1%82%D0%BE%D1%8F%D1%82%D0%B5%D0%BB%D1%8C%D0%BD%D0%B0%D1%8F_%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%B0_3_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Самостоятельная работа 3. Pandas
#
# 1. Скачайте этот ноутбук к себе.
# 2. Заполните пропущенные ячейки, отвечая на заданные вопросы. Там должен быть код! (если не сказано обратное)
# 3. Сохраните результат в своём гитхаб репозитории.
#
# #### Полезная литература
#
# - http://pandas.pydata.org/pandas-docs/stable/10min.html
# - https://pandas.pydata.org/pandas-docs/stable/indexing.html
# - https://pandas.pydata.org/pandas-docs/stable/missing_data.html

# %% [markdown]
# В этом задании мы с вами рассмотрим датасет [Adult Data Set](https://archive.ics.uci.edu/ml/datasets/Adult).
# Основывается он на данных переписи населения 1994 года в США.
#
# Расшифровка содержимого колонок:
#
# - age: continuous.
# - workclass: Private, Self-emp-not-inc, Self-emp-inc, Federal-gov, Local-gov, State-gov, Without-pay, Never-worked.
# - fnlwgt: continuous. sampling weight, more here: SIPP Weighting.
# - education: Bachelors, Some-college, 11th, HS-grad, Prof-school, Assoc-acdm, Assoc-voc, 9th, 7th-8th, 12th, Masters, 1st-4th, 10th, Doctorate, 5th-6th, Preschool.
# - education-num: continuous.
# - marital-status: Married-civ-spouse, Divorced, Never-married, Separated, Widowed, Married-spouse-absent, Married-AF-spouse.
# - occupation: Tech-support, Craft-repair, Other-service, Sales, Exec-managerial, Prof-specialty, Handlers-cleaners, Machine-op-inspct, Adm-clerical, Farming-fishing, Transport-moving, Priv-house-serv, Protective-serv, Armed-Forces.
# - relationship: Wife, Own-child, Husband, Not-in-family, Other-relative, Unmarried.
# - race: White, Asian-Pac-Islander, Amer-Indian-Eskimo, Other, Black.
# - sex: Female, Male.
# - capital-gain: continuous. Income from investment sources, apart from wages/salary.
# - capital-loss: continuous. Losses from investment sources, apart from wages/salary.
# - hours-per-week: continuous.
# - native-country: United-States, Cambodia, England, Puerto-Rico, Canada, Germany, Outlying-US(Guam-USVI-etc), India, Japan, Greece, South, China, Cuba, Iran, Honduras, Philippines, Italy, Poland, Jamaica, Vietnam, Mexico, Portugal, Ireland, France, Dominican-Republic, Laos, Ecuador, Taiwan, Haiti, Columbia, Hungary, Guatemala, Nicaragua, Scotland, Thailand, Yugoslavia, El-Salvador, Trinadad&Tobago, Peru, Hong, Holand-Netherlands.

# %%
# %matplotlib inline
import pandas as pd
pd.__version__
# Out:
# '1.5.3'

# %% [markdown]
# Если вы увидели warning, не переживайте, всё хорошо.
# - https://stackoverflow.com/questions/40845304/runtimewarning-numpy-dtype-size-changed-may-indicate-binary-incompatibility
# - https://github.com/numpy/numpy/pull/432

# %%
columns='age, workclass, fnlwgt, education, education.num, marital.status, occupation, relationship, race, sex, capital.gain, capital.loss, hours.per.week, native.country, income'.split(',')
#df = pd.read_csv('../../data/adult.csv.gz', na_values='?') # можно загрузить из файла или URL
df = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data', na_values='?', names=columns)
df.head()
# Out:
#    age          workclass   fnlwgt   education   education.num  \
# 0   39          State-gov    77516   Bachelors              13
# 1   50   Self-emp-not-inc    83311   Bachelors              13
# 2   38            Private   215646     HS-grad               9
# 3   53            Private   234721        11th               7
# 4   28            Private   338409   Bachelors              13
#
#         marital.status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#     capital.gain   capital.loss   hours.per.week  native.country  income
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              32561 non-null  int64
#  1    workclass       32561 non-null  object
#  2    fnlwgt          32561 non-null  int64
#  3    education       32561 non-null  object
#  4    education.num   32561 non-null  int64
#  5    marital.status  32561 non-null  object
#  6    occupation      32561 non-null  object
#  7    relationship    32561 non-null  object
#  8    race            32561 non-null  object
#  9    sex             32561 non-null  object
#  10   capital.gain    32561 non-null  int64
#  11   capital.loss    32561 non-null  int64
#  12   hours.per.week  32561 non-null  int64
#  13   native.country  32561 non-null  object
#  14   income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df.shape
# Out:
# (32561, 15)

# %% [markdown]
# **1) Выведите последние 10 элеметнов датасета**

# %%
df2 = df.tail(10)
df2
# Out:
#        age      workclass   fnlwgt      education   education.num  \
# 32551   32        Private    34066           10th               6
# 32552   43        Private    84661      Assoc-voc              11
# 32553   32        Private   116138        Masters              14
# 32554   53        Private   321865        Masters              14
# 32555   22        Private   310152   Some-college              10
# 32556   27        Private   257302     Assoc-acdm              12
# 32557   40        Private   154374        HS-grad               9
# 32558   58        Private   151910        HS-grad               9
# 32559   22        Private   201490        HS-grad               9
# 32560   52   Self-emp-inc   287927        HS-grad               9
#
#             marital.status          occupation    relationship  \
# 32551   Married-civ-spouse   Handlers-cleaners         Husband
# 32552   Married-civ-spouse               Sales         Husband
# ...

# %% [markdown]
# **2) Сколько колонок и сколько строк в этом датасете?**

# %%
df.shape
# Out:
# (32561, 15)

# %% [markdown]
# 3) Какие типы данных у элементов этого датасета?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              32561 non-null  int64
#  1    workclass       32561 non-null  object
#  2    fnlwgt          32561 non-null  int64
#  3    education       32561 non-null  object
#  4    education.num   32561 non-null  int64
#  5    marital.status  32561 non-null  object
#  6    occupation      32561 non-null  object
#  7    relationship    32561 non-null  object
#  8    race            32561 non-null  object
#  9    sex             32561 non-null  object
#  10   capital.gain    32561 non-null  int64
#  11   capital.loss    32561 non-null  int64
#  12   hours.per.week  32561 non-null  int64
#  13   native.country  32561 non-null  object
#  14   income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df3 = df.dtypes
print(df3)
# Out:
# age                 int64
#  workclass         object
#  fnlwgt             int64
#  education         object
#  education.num      int64
#  marital.status    object
#  occupation        object
#  relationship      object
#  race              object
#  sex               object
#  capital.gain       int64
#  capital.loss       int64
#  hours.per.week     int64
#  native.country    object
#  income            object
# dtype: object

# %% [markdown]
# **4) Какие признаки имеют пропуски?**

# %%
df.isnull().values.any() #есть ли пустый значения?
# Out:
# False

# %%
with_zeros = df.columns[df.eq(0).any()]       #поиск колонок с нулевыми значениями
with_zeros
# Out:
# Index([' capital.gain', ' capital.loss'], dtype='object')

# %%
with_question = df.columns[df.isin([' ?']).any()]     #поиск колонок с значениями '?', так как из задания 6 мы узнали, что есть рабочий класс "?"
print(with_question)                                  #Так как нет пустых, то проверим таким образом
# Out:
# Index([' workclass', ' occupation', ' native.country'], dtype='object')

# %%
question_values = (df == ' ?').sum() #сколько значений, содержащих '?' по каждой строке?
question_values
# Out:
# age                   0
#  workclass         1836
#  fnlwgt               0
#  education            0
#  education.num        0
#  marital.status       0
#  occupation        1843
#  relationship         0
#  race                 0
#  sex                  0
#  capital.gain         0
#  capital.loss         0
#  hours.per.week       0
#  native.country     583
#  income               0
# dtype: int64

# %% [markdown]
# **5) Как вы думаете, с чем связаны пропуски этих значение. Напишите развернутый ответ в ячейке ниже.**

# %% [markdown]
# **Ваш ответ:**
#
# Пропуски могли возникнуть по разным причинам:
#
# 1. Пропуски могли появиться из-за ошибок при сборе или вводе данных, например, если информация не была введена или была утеряна, например, **рабочий класс**.
#
# 2. Некоторые поля могли быть необязательными, или во время переписи населения в 1994 гражданин США не хотел говорить название своей **родной страны** или не знал свою **родную страну**. Так же скорре всего был предоставлен готовый список на выбор **рода занятия**  и гражданин не стал указывать, т.к. не нашел свой вариант или выбрал до этого в разделе **"рабочий класс"** вариант: **"никогда не работал"**.
#
# 3. Проблемы с техническими системами или программным обеспечением тоже могли привести к потере данных или созданию пропусков в 1994 году.

# %% [markdown]
# **6) Какие и сколько различных рабочих классов workclass представлено в выборке?**

# %%
workclass_counts = df[' workclass'].value_counts()
workclass_counts
# Out:
#  Private             22696
#  Self-emp-not-inc     2541
#  Local-gov            2093
#  ?                    1836
#  State-gov            1298
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name:  workclass, dtype: int64

# %% [markdown]
# **7) Какой средний возраст женщин и мужчин?**

# %%
avg_age_women = df[df[' sex'] == ' Female']['age'].mean()    #средний возраст для женщин
avg_age_men = df[df[' sex'] == ' Male']['age'].mean()        #средний возраст для мужчин
print(f"Средний возраст женщин: {avg_age_women:.2f}")
print(f"Средний возраст мужчин: {avg_age_men:.2f}")
# Out:
# Средний возраст женщин: 36.86
# Средний возраст мужчин: 39.43

# %% [markdown]
# **8) Постройте гистограмму(bar) распределения образования людей (education)**

# %%
import matplotlib.pyplot as plt #для построения гистограммы  используем библиотеку Matplotlib

# %%
education_counts = df[' education'].value_counts() #группировка данных по образованию и подсчет количества людей в каждой категории

# %%
#построение гистограммы
plt.figure(figsize=(7, 4))
education_counts.plot(kind='bar')
plt.title('Распределение образования людей (education)')
plt.show()

# %% [markdown]
# **9) Каковы средние значения и среднеквадратичные отклонения возраста тех, кто получает более 50K в год (признак salary) и тех, кто получает менее 50K в год?**

# %%
mean_age_more_50k = df[df[' income'] == ' >50K']['age'].mean()   #Вычисление среднего возраста
mean_age_less_50k = df[df[' income'] == ' <=50K']['age'].mean()

print("Средний возраст (более 50K в год): ", mean_age_more_50k)
print("Средний возраст (менее 50K в год): ", mean_age_less_50k)
# Out:
# Средний возраст (более 50K в год):  44.24984058155847
# Средний возраст (менее 50K в год):  36.78373786407767

# %%
std_age_more_50k = df[df[' income'] == ' >50K']['age'].std()     #Вычисление стандартного отклонения
std_age_less_50k = df[df[' income'] == ' <=50K']['age'].std()

print("Стандартное отклонение возраста (более 50K в год) :", std_age_more_50k)
print("Стандартное отклонение возраста (менее 50K в год) :", std_age_less_50k)
# Out:
# Стандартное отклонение возраста (более 50K в год) : 10.519027719851826
# Стандартное отклонение возраста (менее 50K в год) : 14.02008849082488

# %% [markdown]
# **10) Правда ли, что люди, которые получают больше 50k, имеют как минимум высшее образование? (признак education - Bachelors, Prof-school, Assoc-acdm, Assoc-voc, Masters или Doctorate)**

# %%
high_education = df[df[' income'] == ' >50K'] #фильтрация данных

# %%
have_high_education = high_education[' education'].isin([' Bachelors', ' Prof-school', ' Assoc-acdm', ' Assoc-voc', ' Masters', ' Doctorate']).all()

if have_high_education:
    print("Да, правда")
else:
    print("Нет, не правда")
# Out:
# Нет, не правда

# %% [markdown]
# **11) Среди кого больше доля зарабатывающих много (>50K): среди женатых или холостых мужчин (признак marital-status)? Женатыми считаем тех, у кого marital-status начинается с Married (Married-civ-spouse, Married-spouse-absent или Married-AF-spouse), остальных считаем холостыми.**

# %%
male = df[df[' sex'] == ' Male']
married_men = df[df[' marital.status'].str.startswith(' Married')]     #группа для женатых
single_men = df[~df[' marital.status'].str.startswith(' Married')]     #группа для холостых

# %%
high_income_married = (married_men[' income'] == ' >50K').mean()       #вычисление доли мужчин, зарабатывающих >50K для женатых
high_income_single = (single_men[' income'] == ' >50K').mean()         #вычисление доли мужчин, зарабатывающих >50K для холостых

# %%
# Сравнение долей и вывод результата
if high_income_married > high_income_single:
    print("Среди женатых мужчин доля зарабатывающих >50K больше .")
elif high_income_married < high_income_single:
    print("Среди холостых мужчин доля зарабатывающих >50K больше .")
else:
    print("Доли зарабатывающих >50K среди женатых и холостых мужчин равны.")
# Out:
# Среди женатых мужчин доля зарабатывающих >50K больше .

# %% [markdown]
# **12) Посчитайте среднее время работы (hours-per-week) зарабатывающих мало и много (salary) для каждой страны (native-country).**

# %%
grouped = df.groupby([' native.country', ' income'])[' hours.per.week'].mean().unstack()
grouped
# Out:
#  income                          <=50K       >50K
#  native.country
#  ?                           40.164760  45.547945
#  Cambodia                    41.416667  40.000000
#  Canada                      37.914634  45.641026
#  China                       37.381818  38.900000
#  Columbia                    38.684211  50.000000
#  Cuba                        37.985714  42.440000
#  Dominican-Republic          42.338235  47.000000
#  Ecuador                     38.041667  48.750000
#  El-Salvador                 36.030928  45.000000
#  England                     40.483333  44.533333
#  France                      41.058824  50.750000
#  Germany                     39.139785  44.977273
#  Greece                      41.809524  50.625000
#  Guatemala                   39.360656  36.666667
#  Haiti                       36.325000  42.750000
#  Holand-Netherlands          40.000000        NaN
#  Honduras                    34.333333  60.000000
# ...

# %% [markdown]
# **13) Постройте сводную таблицу для сравнения уровня образования и разницы между capital.gain и capital.loss (то есть пассивный доход). Сделайте так, чтобы capital.gain - capital.loss создали не больше 10 разных уникальных значений. То есть, gain и loss - это числа в каком-то диапазоне. Это количественные признаки из вещественных чисел. С помощью математических функций, типа log, извлечение корня N-ой степени и округления можно перейти к категориальным признакам.**

# %%
df[' capital.diff'] = df[' capital.gain'] - df[' capital.loss']      #создание нового признака capital.diff (пассивный доход)

# %%
#определение функции для создания не больше 10 разных уникальных значений
def create_range(diff):
    if diff < 0:
        return "Loss"
    elif diff == 0:
        return "No Gain/Loss"
    elif 0 < diff <= 1000:
        return "Low Gain"
    elif 1000 < diff <= 5000:
        return "Medium Gain"
    else:
        return "High Gain"

# %%
df[' capital.diff.range'] = df[' capital.diff'].apply(create_range) #применение функци create_range к столбцу capital.diff для создания диапазонов

# %%
pd.crosstab(df[' education'], df[' capital.diff.range']) #сводная таблица
# Out:
#  capital.diff.range  High Gain  Loss  Low Gain  Medium Gain  No Gain/Loss
#  education
#  10th                       10    28         2           28           865
#  11th                       21    33         5           27          1089
#  12th                        8     8         3           11           403
#  1st-4th                     1     4         0            4           159
#  5th-6th                     5    11         0            9           308
#  7th-8th                     8    23         0           33           582
#  9th                         3     9         4           24           474
#  Assoc-acdm                 49    55         0           33           930
#  Assoc-voc                  71    54         2           61          1194
#  Bachelors                 486   338         3          144          4384
#  Doctorate                  64    53         1           11           284
# ...

# %% [markdown]
# **С помощью математических функций, типа log, извлечение корня N-ой степени и округления можно перейти к категориальным признакам.**

# %% [markdown]
# **14) Женщины из каких стран получают в среднем большую зарплату (>50K) чаще.**

# %%
female = df[df[' sex'] == ' Female']

# %%
grouped = female.groupby([' native.country', ' income']).size().unstack() #группировка данных по стране и уровню заработной платы
grouped
# Out:
#  income                       <=50K    >50K
#  native.country
#  ?                            146.0    17.0
#  Cambodia                       3.0     NaN
#  Canada                        30.0     9.0
#  China                         16.0     5.0
#  Columbia                      24.0     NaN
#  Cuba                          37.0     3.0
#  Dominican-Republic            33.0     2.0
#  Ecuador                        9.0     NaN
#  El-Salvador                   34.0     1.0
#  England                       26.0     6.0
#  France                         9.0     3.0
#  Germany                       53.0     7.0
#  Greece                         4.0     1.0
#  Guatemala                     20.0     NaN
#  Haiti                         19.0     1.0
#  Holand-Netherlands             1.0     NaN
#  Honduras                       6.0     1.0
#  Hong                           5.0     1.0
#  Hungary                        5.0     1.0
#  India                          9.0     2.0
# ...

# %%
grouped[' fraction_high_income'] = grouped[' >50K'] / grouped.sum(axis=1)

# %%
# Нахождение страны с максимальной долей женщин, получающих большую зарплату
country_with_highest_fraction = grouped[' fraction_high_income'].idxmax()

print(country_with_highest_fraction)
# Out:
#  Yugoslavia

# %% [markdown]
# **15) Создайте случайную колонку - magic_salary, которую нужно будет вычислить следующим образом: если зарплата небольшая (<50K), тогда случайно выберите число из диапазона [0,50]. Если зарплата выше 50K тогда из диапазона [51, 200]. Посчитайте среднюю зарплату в час для групп людей с одни уровнем образования на основе нашей случайной колонки magic_salary**

# %%
import numpy as np

# %%
def generate_magic_salary(row):             #создание случайной колонки magic_salary
    if row[' income'] == ' <=50K':
        return np.random.randint(0, 51)
    elif row[' income'] == ' >50K':
        return np.random.randint(51, 201)
    else:
        return np.nan

df['magic_salary'] = df.apply(generate_magic_salary, axis=1)

# %%
mean_salary = df.groupby(' education')['magic_salary'].mean()    #вычисление средней зарплаты в час для групп людей с одним уровнем образования
mean_salary
# Out:
#  education
#  10th             31.161844
#  11th             30.312340
#  12th             32.715935
#  1st-4th          29.821429
#  5th-6th          30.108108
#  7th-8th          30.869969
#  9th              29.857977
#  Assoc-acdm       50.631678
#  Assoc-voc        51.312590
#  Bachelors        66.424090
#  Doctorate       100.421308
#  HS-grad          40.651462
#  Masters          81.567615
#  Preschool        25.803922
#  Prof-school     100.223958
#  Some-college     44.446029
# Name: magic_salary, dtype: float64
