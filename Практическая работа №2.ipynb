# %% [markdown]
# <a href="https://colab.research.google.com/github/ponomarevaJV/PDA_SOL/blob/main/%D0%9F%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D1%87%D0%B5%D1%81%D0%BA%D0%B0%D1%8F%20%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%B0%20%E2%84%962.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
plt.xlim(0, 100)
plt.ylim(0, 200)
x = [0,50]
y = [0,148]
a = plt.plot (x,y)
plt.title('Отрисовка линии')
plt.xlabel ('Ось X')
plt.ylabel ('Ось Y')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.ylim(0, 25)
xscale=10
x = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]
x_pos = [i for i, _ in enumerate(x)]
plt.bar(x_pos, popularity, color=(0.4, 0.6, 0.8, 1.0))
plt.xlabel("Languages")
plt.ylabel("Popularity")
plt.title("PopularitY of Programming Language\n" + "Worldwide, Oct 2017 compared to a year ago")
plt.xticks(x_pos, x, rotation=90)
plt.subplots_adjust(bottom=.4, top=.8)
plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth='0.5', color='red')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
df =  pd.read_csv('/content/drive/MyDrive/Python /Практическая работа 2 /1.csv')
country_data = df["country"]
medal_data = df["gold_medal"]
colors = ["#1f77b4", "#ff7f0e", "#2ca02c", "#d62728", "#8c564b"]
explode = (0.1, 0, 0, 0, 0)
plt.pie(medal_data, labels=country_data, explode=explode, colors=colors,
autopct='%1.1f%%', shadow=True, startangle=140)
plt.title("Gold medal achievements of five most successful\n"+"countries in 2016 Summer Olympics")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.xlim(55, 75)
plt.ylim(80, 260)
weight1=[56,57.5,61,62,63,64,64.5,68,71,72]
height1=[118,199,150,151,181,125,126,190,181,140]
weight2=[57,59,61,61.1,62.5,64,69,68.8,71,72]
height2=[127,99,158,198,150,152,138.5,165,168,172]
weight3=[56.5,59,61,62.5,62.6,65.2,67.5,67.1,71,70]
height3=[119,125,138,137,163,138,104,170,161,235]
weight=np.concatenate((weight1,weight2,weight3))
height=np.concatenate((height1,height2,height3))
plt.scatter(weight1, height1, marker='*', color=['green'])
plt.scatter(weight2, height2, marker='*', color=['blue'])
plt.scatter(weight3, height3, marker='*', color=['red'])
plt.xlabel('weight', fontsize=10)
plt.ylabel('height', fontsize=10)
plt.title('Group wise Weight vs Height scatter plot',fontsize=18)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
df =  pd.read_csv('/content/drive/MyDrive/Python /Практическая работа 2 /corruption.csv')
df.head (10)
# Out:
#        country  annual_income  corruption_index
# 0      Denmark          68110                12
# 1      Finland          53660                12
# 2  New Zealand          45340                12
# 3       Norway          84090                15
# 4    Singapore          64010                15
# 5       Sweden          58890                15
# 6  Switzerland          90360                16
# 7  Netherlands          56370                18
# 8   Luxembourg          81110                19
# 9      Germany          51040                20

# %%
df.shape
# Out:
# (110, 3)

# %%
df.dtypes
# Out:
# country             object
# annual_income        int64
# corruption_index     int64
# dtype: object

# %%
df.isnull().sum().sum ()
# Out:
# 0

# %%
print("Максимальное значение в столбце 'annual_income':", df.annual_income.max())
print("Минимальное значение в столбце 'annual_income':", df.annual_income.min())
# Out:
# Максимальное значение в столбце 'annual_income': 90360
# Минимальное значение в столбце 'annual_income': 240

# %%
print("Максимальное значение в столбце 'corruption_index':", df.corruption_index.max())
print("Минимальное значение в столбце 'corruption_index':", df.corruption_index.min())
# Out:
# Максимальное значение в столбце 'corruption_index': 89
# Минимальное значение в столбце 'corruption_index': 12

# %%
df2 = df.tail(10)
df2
# Out:
#                    country  annual_income  corruption_index
# 100  Congo (Dem. Republic)            580                81
# 101           Turkmenistan           7220                81
# 102      Equatorial Guinea           5810                83
# 103                  Libya           8430                83
# 104            Afghanistan            500                84
# 105                  Yemen            670                84
# 106              Venezuela          13080                86
# 107                Somalia            450                87
# 108                  Syria           1170                87
# 109            South Sudan            460                89

# %%
x  = ['Denmark','Finland', 'New Zealand','Norway','Singapore',]
y1 = [68110,53660,45340,84090,64010]
y2 = [12,12,12,15,15]
plt.plot(x, y1, label="annual_income")
plt.plot(x, y2, label="corruption_index")
plt.plot()

plt.xlabel("x")
plt.ylabel("y")
plt.title("Line Graph Example")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
plt.ylim(0, 90000)
xscale=10
x = ['Denmark','Finland', 'New Zealand','Norway','Singapore']
annual_income = [68110,53660,45340,84090,64010]
x_pos = [i for i, _ in enumerate(x)]
plt.bar(x_pos, annual_income, color=(0.4, 0.6, 0.8, 1.0))
plt.xlabel("Country")
plt.ylabel("annual_income")
plt.title("annual_income- country")
plt.xticks(x_pos, x, rotation=90)
plt.subplots_adjust(bottom=.4, top=.8)
plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth='0.5', color='red')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()

# %%
sum = df['annual_income'].sum()
print(sum)
# Out:
# 1891530

# %%
labels = 'Общий годовой доход всех стран', 'Switzerland'
sections = [95,5]
colors = ['c', 'g']

plt.pie(sections, labels=labels, colors=colors,
        startangle=90,
        explode = (0, 0.1,),
        autopct = '%1.2f%%')

plt.axis('equal') # Try commenting this out.
plt.title('Общий доход стран к доходу швейцарии')
plt.show()

# %%
df.plot.hexbin(x='corruption_index', y='annual_income', gridsize= 20)
# Out:
# <Axes: xlabel='corruption_index', ylabel='annual_income'>

# %%
sns.heatmap(df)
plt.figure(figsize = (12,8))

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import axes3d

fig = plt.figure()
ax = fig.add_subplot(111, projection = '3d')

x1 = [ 1,2,3,4,5]
y1 = [68110,53660,45340,84090,64010]
z1 = [12,12,12,15,15]

x2 = [1,2,3,4,5]
y2 = [68110,53660,45340,84090,64010]
z2 = [12,12,12,15,15]

ax.scatter(x1, y1, z1, c='b', marker='o', label='blue')
ax.scatter(x2, y2, z2, c='g', marker='D', label='green')

ax.set_xlabel('country')
ax.set_ylabel('annual_income')
ax.set_zlabel('corruption_index')
plt.title("The first five countries")
plt.legend()
plt.tight_layout()
plt.show()
